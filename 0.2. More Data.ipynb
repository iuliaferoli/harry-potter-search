# %%
from elasticsearch import Elasticsearch
from elasticsearch.helpers import bulk

import configparser

config = configparser.ConfigParser()
config.read('foobar.ini')
cloud_id = config["cloud-connection"]["cloud_id"]
user = config["cloud-connection"]["user"] # by default user = "elastic"
password = config["cloud-connection"]["password"]

client = Elasticsearch(
    cloud_id=cloud_id,  # cloud id can be found under deployment management
    basic_auth=(user, password) # your username and password for connecting to elastic, found under Deplouments - Security
)

client.info()
# Out:
# ObjectApiResponse({'name': 'instance-0000000000', 'cluster_name': 'fdcc4e10e5a34385884a3eda9350099a', 'cluster_uuid': '1v8os-EZTPmrZoF6uXeWKA', 'version': {'number': '8.9.0', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': '8aa461beb06aa0417a231c345a1b8c38fb498a0d', 'build_date': '2023-07-19T14:43:58.555259655Z', 'build_snapshot': False, 'lucene_version': '9.7.0', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'})

# %%
import re
import pandas as pd 

hp_script = pd.read_csv("data/Harry_Potter_2.csv", sep = ";" )
hp_script = hp_script.applymap(lambda x: re.sub(r'[^ \w+]', '', str(x).strip()))
hp_script["Line_number"] = hp_script.index
hp_script.head()
# Out:
#   Character                                       Sentence  Line_number
# 0     HARRY                      I cant let you out Hedwig            0
# 1     HARRY  Im not allowed to use magic outside of school            1
# 2     HARRY                        Besides if Uncle Vernon            2
# 3    VERNON                                   Harry Potter            3
# 4     HARRY                              Now youve done it            4

# %%
index = "hp_script_2"
settings = {}
mappings = {
    "_meta" : {
        "created_by" : "Iulia Feroli"
    },
    "properties" : {
        "Line_number" : {
            "type" : "long"
        },
        "Character" : {
            "type" : "keyword",
            "type" : "text"
        },
        "Sentence" : {
            "type" : "text"
        }
    }
}

client.indices.create(index=index, settings=settings, mappings=mappings)

# %%
from json import loads
docs = hp_script.to_json(orient = "records")
hp_script_docs_2 = loads(docs)
hp_script_docs_2[0:5]
# Out:
# [{'Character': 'HARRY',
#   'Sentence': 'I cant let you out Hedwig',
#   'Line_number': 0},
#  {'Character': 'HARRY',
#   'Sentence': 'Im not allowed to use magic outside of school',
#   'Line_number': 1},
#  {'Character': 'HARRY',
#   'Sentence': 'Besides if Uncle Vernon',
#   'Line_number': 2},
#  {'Character': 'VERNON', 'Sentence': 'Harry Potter', 'Line_number': 3},
#  {'Character': 'HARRY', 'Sentence': 'Now youve done it', 'Line_number': 4}]

# %%
response = bulk(client = client, index = index, actions = iter(hp_script_docs), stats_only = True )

# %%
import re
hp_script = pd.read_csv("data/Harry_Potter_3.csv", sep = ";" )
hp_script = hp_script.applymap(lambda x: re.sub(r'[^ \w+]', '', str(x).strip()))
hp_script["Line_number"] = hp_script.index
hp_script.rename(columns = {'CHARACTER':'Character'}, inplace = True)
hp_script.rename(columns = {'SENTENCE':'Sentence'}, inplace = True)

index = "hp_script_3"
#client.indices.create(index=index, settings=settings, mappings=mappings)

docs = hp_script.to_json(orient = "records")
hp_script_docs_3 = loads(docs)
hp_script_docs_3[0:5]

#response = bulk(client = client, index = index, actions = iter(hp_script_docs_3), stats_only = True )
# Out:
# [{'Character': 'HARRY', 'Sentence': 'Lumos Maxima', 'Line_number': 0},
#  {'Character': 'HARRY', 'Sentence': 'Lumos Maxima', 'Line_number': 1},
#  {'Character': 'HARRY', 'Sentence': 'Lumos Maxima', 'Line_number': 2},
#  {'Character': 'HARRY', 'Sentence': 'Lumos MAXIMA', 'Line_number': 3},
#  {'Character': 'AUNT PETUNIA', 'Sentence': 'Harry Harry', 'Line_number': 4}]

# %%
hp_script = pd.read_csv("data/Harry_Potter_1.csv", sep = ";" )
hp_script = hp_script.applymap(lambda x: re.sub(r'[^ \w+]', '', str(x).strip()))
hp_script["Line_number"] = hp_script.index

docs = hp_script.to_json(orient = "records")
hp_scripts = loads(docs)

# %%
hp_scripts = hp_scripts + hp_script_docs_2 + hp_script_docs_3

# %%
index = "hp_scripts"
client.indices.create(index=index, settings=settings, mappings=mappings)
response = bulk(client = client, index = index, actions = iter(hp_scripts), stats_only = True )

# %%
hp_scripts
# Out:
# [{'Character': 'Dumbledore',
#   'Sentence': 'I shouldve known that you would be here Professor McGonagall',
#   'Line_number': 0},
#  {'Character': 'McGonagall',
#   'Sentence': 'Good evening Professor Dumbledore',
#   'Line_number': 1},
#  {'Character': 'McGonagall',
#   'Sentence': 'Are the rumors true Albus',
#   'Line_number': 2},
#  {'Character': 'Dumbledore',
#   'Sentence': 'Im afraid so professor',
#   'Line_number': 3},
#  {'Character': 'Dumbledore',
#   'Sentence': 'The good and the bad',
#   'Line_number': 4},
#  {'Character': 'McGonagall', 'Sentence': 'And the boy', 'Line_number': 5},
#  {'Character': 'Dumbledore',
#   'Sentence': 'Hagrid is bringing him',
#   'Line_number': 6},
#  {'Character': 'McGonagall',
#   'Sentence': 'Do you think it wise to trust Hagrid with something as important as this',
#   'Line_number': 7},
#  {'Character': 'Dumbledore',
#   'Sentence': 'Ah Professor I would trust Hagrid with my life',
#   'Line_number': 8},
#  {'Character': 'Hagrid',
#   'Sentence': 'Professor Dumbledore sir',
#   'Line_number': 9},
#  {'Character': 'Hagrid',
#   'Sentence': 'Professor McGonagall',
#   'Line_number': 10},
#  {'Character': 'Dumbledore',
#   'Sentence': 'No problems I trust Hagrid',
#   'Line_number': 11},
#  {'Character': 'Hagrid', 'Sentence': 'No sir', 'Line_number': 12},
#  {'Character': 'Hagrid',
#   'Sentence': 'Little tyke fell asleep just as we were flying over Bristol',
#   'Line_number': 13},
#  {'Character': 'Hagrid', 'Sentence': 'Try not to wake him', 'Line_number': 14},
#  {'Character': 'Hagrid', 'Sentence': 'There you go', 'Line_number': 15},
#  {'Character': 'Dumbledore',
#   'Sentence': 'Albus do you really think its safe leaving him with these people',
#   'Line_number': 16},
#  {'Character': 'McGonagall',
#   'Sentence': 'Ive watched them all day',
#   'Line_number': 17},
#  {'Character': 'McGonagall',
#   'Sentence': 'Theyre the worst sort of Muggles imaginable',
#   'Line_number': 18},
#  {'Character': 'McGonagall', 'Sentence': 'They really are', 'Line_number': 19},
#  {'Character': 'Dumbledore',
#   'Sentence': 'The only family he has',
#   'Line_number': 20},
#  {'Character': 'McGonagall',
#   'Sentence': 'This boy will be famous',
#   'Line_number': 21},
#  {'Character': 'McGonagall',
#   'Sentence': 'There wont be a child in our world who doesnt know his name',
#   'Line_number': 22},
#  {'Character': 'Dumbledore', 'Sentence': 'Exactly', 'Line_number': 23},
#  {'Character': 'Dumbledore',
#   'Sentence': 'Hes far better off growing up away from all of that',
#   'Line_number': 24},
#  {'Character': 'Dumbledore', 'Sentence': 'Until hes ready', 'Line_number': 25},
#  {'Character': 'Dumbledore',
#   'Sentence': 'There there Hagrid',
#   'Line_number': 26},
#  {'Character': 'Dumbledore',
#   'Sentence': 'Its not really goodbye after all',
#   'Line_number': 27},
#  {'Character': 'Dumbledore',
#   'Sentence': 'Good luckHarry Potter',
#   'Line_number': 28},
#  {'Character': 'Petunia', 'Sentence': 'Up Get up', 'Line_number': 29},
#  {'Character': 'Petunia', 'Sentence': 'Now', 'Line_number': 30},
#  {'Character': 'Dudley', 'Sentence': 'Wake up cousin', 'Line_number': 31},
#  {'Character': 'Dudley',
#   'Sentence': 'Were going to the zoo',
#   'Line_number': 32},
#  {'Character': 'Petunia',
#   'Sentence': 'Here he comes the birthday boy',
#   'Line_number': 33},
#  {'Character': 'Vernon', 'Sentence': 'Happy birthday son', 'Line_number': 34},
#  {'Character': 'Petunia',
#   'Sentence': 'Why dont you just cook the breakfast and try not to burn anything',
#   'Line_number': 35},
#  {'Character': 'Harry', 'Sentence': 'Yes Aunt Petunia', 'Line_number': 36},
#  {'Character': 'Petunia',
#   'Sentence': 'I want everything to be perfect for my Dudleys special day',
#   'Line_number': 37},
#  {'Character': 'Vernon',
#   'Sentence': 'Hurry up Bring my coffee boy',
#   'Line_number': 38},
#  {'Character': 'Harry', 'Sentence': 'Yes Uncle Vernon', 'Line_number': 39},
#  {'Character': 'Petunia',
#   'Sentence': 'Arent they wonderful darling',
#   'Line_number': 40},
#  {'Character': 'Dudley', 'Sentence': 'How many are there', 'Line_number': 41},
#  {'Character': 'Vernon',
#   'Sentence': '36 Counted them myself',
#   'Line_number': 42},
#  {'Character': 'Dudley',
#   'Sentence': '36 But last year last year I had 37',
#   'Line_number': 43},
#  {'Character': 'Vernon',
#   'Sentence': 'But some of them are quite a bit bigger than last years',
#   'Line_number': 44},
#  {'Character': 'Dudley',
#   'Sentence': 'I dont care how big they are',
#   'Line_number': 45},
#  {'Character': 'Petunia', 'Sentence': 'Oh now now now', 'Line_number': 46},
#  {'Character': 'Petunia',
#   'Sentence': 'This is what were going to do',
#   'Line_number': 47},
#  {'Character': 'Petunia',
#   'Sentence': 'is that when we go out were going to buy you two new presents',
#   'Line_number': 48},
#  {'Character': 'Petunia', 'Sentence': 'Hows that pumpkin', 'Line_number': 49},
#  {'Character': 'Petunia',
#   'Sentence': 'It should be a lovely day at the zoo',
#   'Line_number': 50},
#  {'Character': 'Petunia',
#   'Sentence': 'Im really looking forward to it',
#   'Line_number': 51},
#  {'Character': 'Vernon',
#   'Sentence': 'Im warning you now boy',
#   'Line_number': 52},
#  {'Character': 'Vernon',
#   'Sentence': 'Any funny business any at all',
#   'Line_number': 53},
#  {'Character': 'Vernon',
#   'Sentence': 'And you wont have any meals for a week',
#   'Line_number': 54},
#  {'Character': 'Vernon', 'Sentence': 'Get in', 'Line_number': 55},
#  {'Character': 'Dudley', 'Sentence': 'Make it move', 'Line_number': 56},
#  {'Character': 'Vernon', 'Sentence': 'Move', 'Line_number': 57},
#  {'Character': 'Dudley', 'Sentence': 'Move', 'Line_number': 58},
#  {'Character': 'Harry', 'Sentence': 'Hes asleep', 'Line_number': 59},
#  {'Character': 'Dudley', 'Sentence': 'Hes boring', 'Line_number': 60},
#  {'Character': 'Harry', 'Sentence': 'Sorry about him', 'Line_number': 61},
#  {'Character': 'Harry',
#   'Sentence': 'He doesnt understand what its like lying there day after day',
#   'Line_number': 62},
#  {'Character': 'Harry',
#   'Sentence': 'watching people press their ugly faces in on you',
#   'Line_number': 63},
#  {'Character': 'Harry', 'Sentence': 'Can you hear me', 'Line_number': 64},
#  {'Character': 'Harry',
#   'Sentence': 'Its just Ive never talked to a snake before',
#   'Line_number': 65},
#  {'Character': 'Harry', 'Sentence': 'Do you', 'Line_number': 66},
#  {'Character': 'Harry',
#   'Sentence': 'I mean do you talk to people often',
#   'Line_number': 67},
#  {'Character': 'Harry',
#   'Sentence': 'Youre from Burma arent you',
#   'Line_number': 68},
#  {'Character': 'Harry', 'Sentence': 'Was it nice there', 'Line_number': 69},
#  {'Character': 'Harry',
#   'Sentence': 'Do you miss your family',
#   'Line_number': 70},
#  {'Character': 'Harry',
#   'Sentence': 'I see Thats me as well',
#   'Line_number': 71},
#  {'Character': 'Harry',
#   'Sentence': 'I never knew my parents either',
#   'Line_number': 72},
#  {'Character': 'Harry', 'Sentence': 'Mummy Dad come here', 'Line_number': 73},
#  {'Character': 'Dudley',
#   'Sentence': 'you wont believe what this snake is doing',
#   'Line_number': 74},
#  {'Character': 'Snake', 'Sentence': 'Thanks', 'Line_number': 75},
#  {'Character': 'Harry', 'Sentence': 'Anytime', 'Line_number': 76},
#  {'Character': 'Someone', 'Sentence': 'Snake', 'Line_number': 77},
#  {'Character': 'Dudley', 'Sentence': 'Mum Mummy Help me', 'Line_number': 78},
#  {'Character': 'Petunia', 'Sentence': 'My darling boy', 'Line_number': 79},
#  {'Character': 'Petunia',
#   'Sentence': 'How did you get in there',
#   'Line_number': 80},
#  {'Character': 'Petunia', 'Sentence': 'Who did this', 'Line_number': 81},
#  {'Character': 'Petunia',
#   'Sentence': 'How did you get in there',
#   'Line_number': 82},
#  {'Character': 'Petunia', 'Sentence': 'ls there a snake', 'Line_number': 83},
#  {'Character': 'Petunia',
#   'Sentence': 'Its all right sweetheart',
#   'Line_number': 84},
#  {'Character': 'Petunia',
#   'Sentence': 'Well get you out of these cold clothes',
#   'Line_number': 85},
#  {'Character': 'Vernon', 'Sentence': 'What happened', 'Line_number': 86},
#  {'Character': 'Harry', 'Sentence': 'I swear I dont know', 'Line_number': 87},
#  {'Character': 'Harry',
#   'Sentence': 'One minute the glass was there and then it was gone it was like magic',
#   'Line_number': 88},
#  {'Character': 'Vernon',
#   'Sentence': 'Theres no such thing as magic',
#   'Line_number': 89},
#  {'Character': 'Petunia', 'Sentence': 'And smile', 'Line_number': 90},
#  {'Character': 'Petunia',
#   'Sentence': 'Vernon just look at him',
#   'Line_number': 91},
#  {'Character': 'Petunia', 'Sentence': 'I cant believe it', 'Line_number': 92},
#  {'Character': 'Petunia',
#   'Sentence': 'In just a week hell be off to Smeltings',
#   'Line_number': 93},
#  {'Character': 'Vernon', 'Sentence': 'Caveat Smeltonia', 'Line_number': 94},
#  {'Character': 'Vernon',
#   'Sentence': 'Proudest moment of my life',
#   'Line_number': 95},
#  {'Character': 'Harry',
#   'Sentence': 'Will I have to wear that too',
#   'Line_number': 96},
#  {'Character': 'Petunia',
#   'Sentence': 'What You Go to Smeltings',
#   'Line_number': 97},
#  {'Character': 'Petunia', 'Sentence': 'Dont be so stupid', 'Line_number': 98},
#  {'Character': 'Petunia',
#   'Sentence': 'Youre going to go to the state school',
#   'Line_number': 99},
#  {'Character': 'Petunia', 'Sentence': 'Where you belong', 'Line_number': 100},
#  {'Character': 'Petunia',
#   'Sentence': 'This is what youll going to be wearing when I finish dyeing it',
#   'Line_number': 101},
#  {'Character': 'Harry',
#   'Sentence': 'Thats Dudleys old uniform',
#   'Line_number': 102},
#  {'Character': 'Harry',
#   'Sentence': 'Itll fit me like bits of old elephant skin',
#   'Line_number': 103},
#  {'Character': 'Petunia',
#   'Sentence': 'Itll fit you well enough',
#   'Line_number': 104},
#  {'Character': 'Petunia',
#   'Sentence': 'Go get the post Go',
#   'Line_number': 105},
#  {'Character': 'Vernon',
#   'Sentence': 'Marge is ill Ate a funny whelk',
#   'Line_number': 106},
#  {'Character': 'Dudley',
#   'Sentence': 'Dad look Harrys got a letter',
#   'Line_number': 107},
#  {'Character': 'Harry',
#   'Sentence': 'Hey give it back Its mine',
#   'Line_number': 108},
#  {'Character': 'Vernon',
#   'Sentence': 'Yours Whod be writing to you',
#   'Line_number': 109},
#  {'Character': 'Vernon',
#   'Sentence': 'No more mail through this letterbox',
#   'Line_number': 110},
#  {'Character': 'Petunia',
#   'Sentence': 'Have a lovely day at the office dear',
#   'Line_number': 111},
#  {'Character': 'Vernon', 'Sentence': 'Shoo Go on', 'Line_number': 112},
#  {'Character': 'Vernon', 'Sentence': 'Fine day Sunday', 'Line_number': 113},
#  {'Character': 'Vernon',
#   'Sentence': 'In my opinion best day of the week',
#   'Line_number': 114},
#  {'Character': 'Vernon', 'Sentence': 'Why is that Dudley', 'Line_number': 115},
#  {'Character': 'Harry',
#   'Sentence': 'Because theres no post on Sundays',
#   'Line_number': 116},
#  {'Character': 'Vernon',
#   'Sentence': 'Right you are Harry',
#   'Line_number': 117},
#  {'Character': 'Vernon', 'Sentence': 'No post on Sunday', 'Line_number': 118},
#  {'Character': 'Vernon',
#   'Sentence': 'No blasted letters today No sir',
#   'Line_number': 119},
#  {'Character': 'Vernon',
#   'Sentence': 'Not one single bloody letter Not one',
#   'Line_number': 120},
#  {'Character': 'Vernon',
#   'Sentence': 'No sir not one blasted miserable',
#   'Line_number': 121},
#  {'Character': 'Dudley', 'Sentence': 'Stop it', 'Line_number': 122},
#  {'Character': 'Dudley',
#   'Sentence': 'Mummy whats happening',
#   'Line_number': 123},
#  {'Character': 'Vernon', 'Sentence': 'Give me that', 'Line_number': 124},
#  {'Character': 'Vernon',
#   'Sentence': 'Give me that letter',
#   'Line_number': 125},
#  {'Character': 'Harry', 'Sentence': 'Get off', 'Line_number': 126},
#  {'Character': 'Harry', 'Sentence': 'Theyre my letters', 'Line_number': 127},
#  {'Character': 'Harry', 'Sentence': 'Let go of me', 'Line_number': 128},
#  {'Character': 'Vernon', 'Sentence': 'Thats it', 'Line_number': 129},
#  {'Character': 'Vernon', 'Sentence': 'Were going away', 'Line_number': 130},
#  {'Character': 'Vernon',
#   'Sentence': 'Far away where they cant find us',
#   'Line_number': 131},
#  {'Character': 'Dudley',
#   'Sentence': 'Daddys gone mad hasnt he',
#   'Line_number': 132},
#  {'Character': 'Harry', 'Sentence': 'Make a wish Harry', 'Line_number': 133},
#  {'Character': 'Vernon', 'Sentence': 'Whos there', 'Line_number': 134},
#  {'Character': 'Hagrid', 'Sentence': 'Sorry about that', 'Line_number': 135},
#  {'Character': 'Vernon',
#   'Sentence': 'I demand that you leave at once Sir',
#   'Line_number': 136},
#  {'Character': 'Vernon',
#   'Sentence': 'You are breaking and entering',
#   'Line_number': 137},
#  {'Character': 'Hagrid',
#   'Sentence': 'Dry up Dursley you great prune',
#   'Line_number': 138},
#  {'Character': 'Hagrid',
#   'Sentence': 'Mind I havent seen you since you was a baby Harry',
#   'Line_number': 139},
#  {'Character': 'Hagrid',
#   'Sentence': 'But youre a bit more along than I would have expected',
#   'Line_number': 140},
#  {'Character': 'Hagrid',
#   'Sentence': 'Particularly round the middle',
#   'Line_number': 141},
#  {'Character': 'Dudley', 'Sentence': 'Im not Harry', 'Line_number': 142},
#  {'Character': 'Harry', 'Sentence': 'I am', 'Line_number': 143},
#  {'Character': 'Hagrid',
#   'Sentence': 'Well of course you are',
#   'Line_number': 144},
#  {'Character': 'Hagrid',
#   'Sentence': 'Got something for you',
#   'Line_number': 145},
#  {'Character': 'Hagrid',
#   'Sentence': 'Afraid I might have sat on it at somepoint but I imagine itll taste fine just the same',
#   'Line_number': 146},
#  {'Character': 'Hagrid',
#   'Sentence': 'Baked it myself words and all',
#   'Line_number': 147},
#  {'Character': 'Harry', 'Sentence': 'Thank you', 'Line_number': 148},
#  {'Character': 'Hagrid',
#   'Sentence': 'Its not every day that your young man turns 11 now is it',
#   'Line_number': 149},
#  {'Character': 'Harry',
#   'Sentence': 'Excuse me who are you',
#   'Line_number': 150},
#  {'Character': 'Hagrid',
#   'Sentence': 'Rubeus Hagrid Keeper of Keys and Grounds at Hogwarts',
#   'Line_number': 151},
#  {'Character': 'Hagrid',
#   'Sentence': 'Of course you know all about Hogwarts',
#   'Line_number': 152},
#  {'Character': 'Harry', 'Sentence': 'Sorry no', 'Line_number': 153},
#  {'Character': 'Hagrid',
#   'Sentence': 'No Blimey Harry didnt you ever wonder where your mum and dad learned it all',
#   'Line_number': 154},
#  {'Character': 'Harry', 'Sentence': 'Learnt what', 'Line_number': 155},
#  {'Character': 'Hagrid',
#   'Sentence': 'Youre a wizard Harry',
#   'Line_number': 156},
#  {'Character': 'Harry', 'Sentence': 'Im a what', 'Line_number': 157},
#  {'Character': 'Hagrid', 'Sentence': 'A wizard', 'Line_number': 158},
#  {'Character': 'Hagrid',
#   'Sentence': 'And a thumping good one Id wager once youre trained up little',
#   'Line_number': 159},
#  {'Character': 'Harry',
#   'Sentence': 'No youve made a mistake',
#   'Line_number': 160},
#  {'Character': 'Harry',
#   'Sentence': 'I meanl cant be a wizard',
#   'Line_number': 161},
#  {'Character': 'Harry',
#   'Sentence': 'I mean Im just Harry',
#   'Line_number': 162},
#  {'Character': 'Harry', 'Sentence': 'Just Harry', 'Line_number': 163},
#  {'Character': 'Hagrid',
#   'Sentence': 'Well Just Harry did you ever make anything happen',
#   'Line_number': 164},
#  {'Character': 'Hagrid',
#   'Sentence': 'Anything you couldnt explain when you were angry or scared',
#   'Line_number': 165},
#  {'Character': 'Harry', 'Sentence': 'Dear Mr Potter', 'Line_number': 166},
#  {'Character': 'Harry',
#   'Sentence': 'We are pleased to inform you that you have been accepted at Hogwarts School of Witchcraft and Wizardry',
#   'Line_number': 167},
#  {'Character': 'Vernon',
#   'Sentence': 'He will not be going there',
#   'Line_number': 168},
#  {'Character': 'Vernon',
#   'Sentence': 'We swore when we took him in wed put a stop to all this rubbish',
#   'Line_number': 169},
#  {'Character': 'Harry', 'Sentence': 'You knew', 'Line_number': 170},
#  {'Character': 'Harry',
#   'Sentence': 'You knew all along and you never told me',
#   'Line_number': 171},
#  {'Character': 'Petunia', 'Sentence': 'Of course we knew', 'Line_number': 172},
#  {'Character': 'Petunia',
#   'Sentence': 'How could you not be',
#   'Line_number': 173},
#  {'Character': 'Petunia',
#   'Sentence': 'My perfect sister being who she was',
#   'Line_number': 174},
#  {'Character': 'Petunia',
#   'Sentence': 'My mother and father were so proud the day she got her letter',
#   'Line_number': 175},
#  {'Character': 'Petunia',
#   'Sentence': 'We have a witch in the family',
#   'Line_number': 176},
#  {'Character': 'Petunia', 'Sentence': 'Isnt it wonderful', 'Line_number': 177},
#  {'Character': 'Petunia',
#   'Sentence': 'I was the only one to see her for what she was',
#   'Line_number': 178},
#  {'Character': 'Petunia', 'Sentence': 'A freak', 'Line_number': 179},
#  {'Character': 'Petunia',
#   'Sentence': 'Then she met that Potter and then she had you',
#   'Line_number': 180},
#  {'Character': 'Petunia',
#   'Sentence': 'and I knew you would be the same',
#   'Line_number': 181},
#  {'Character': 'Petunia',
#   'Sentence': 'Just as strange just as abnormal',
#   'Line_number': 182},
#  {'Character': 'Petunia',
#   'Sentence': 'And then if you please she went and got herself blown up',
#   'Line_number': 183},
#  {'Character': 'Petunia',
#   'Sentence': 'And we got landed with you',
#   'Line_number': 184},
#  {'Character': 'Harry', 'Sentence': 'Blown up', 'Line_number': 185},
#  {'Character': 'Harry',
#   'Sentence': 'You told me my parents died in a car crash',
#   'Line_number': 186},
#  {'Character': 'Hagrid', 'Sentence': 'A car crash', 'Line_number': 187},
#  {'Character': 'Hagrid',
#   'Sentence': 'A car crash killed Lily and James Potter',
#   'Line_number': 188},
#  {'Character': 'Petunia',
#   'Sentence': 'We had to say something',
#   'Line_number': 189},
#  {'Character': 'Hagrid', 'Sentence': 'Its an outrage', 'Line_number': 190},
#  {'Character': 'Hagrid', 'Sentence': 'Its a scandal', 'Line_number': 191},
#  {'Character': 'Vernon', 'Sentence': 'Hell not be going', 'Line_number': 192},
#  {'Character': 'Hagrid',
#   'Sentence': 'Oh and I suppose a great Muggle like yourselfs going to stop him are you',
#   'Line_number': 193},
#  {'Character': 'Harry', 'Sentence': 'Muggle', 'Line_number': 194},
#  {'Character': 'Hagrid', 'Sentence': 'Nonmagic folk', 'Line_number': 195},
#  {'Character': 'Hagrid',
#   'Sentence': 'This boys had his name down ever since he were born',
#   'Line_number': 196},
#  {'Character': 'Hagrid',
#   'Sentence': 'Hes going to the finest school of witchcraft and wizardry in the world and',
#   'Line_number': 197},
#  {'Character': 'Hagrid',
#   'Sentence': 'hell be under the finest headmaster that Hogwarts has ever seen Albus Dumbledore',
#   'Line_number': 198},
#  {'Character': 'Vernon',
#   'Sentence': 'I will not pay to have some crackpot old fool teach him magic tricks',
#   'Line_number': 199},
#  {'Character': 'Hagrid',
#   'Sentence': 'Never insult Albus Dumbledore in front of me',
#   'Line_number': 200},
#  {'Character': 'Hagrid',
#   'Sentence': 'Oh um Id appreciate it if you didnt tell anyone at Hogwarts about that',
#   'Line_number': 201},
#  {'Character': 'Hagrid',
#   'Sentence': 'Strickly speaking Im not allowed to do magic',
#   'Line_number': 202},
#  {'Character': 'Harry', 'Sentence': 'Okay', 'Line_number': 203},
#  {'Character': 'Hagrid',
#   'Sentence': 'Ooh Were a bit behind schedule',
#   'Line_number': 204},
#  {'Character': 'Hagrid', 'Sentence': 'Best be off', 'Line_number': 205},
#  {'Character': 'Hagrid',
#   'Sentence': 'Unless youd rather stay of course',
#   'Line_number': 206},
#  {'Character': 'Harry',
#   'Sentence': 'First years students will require three sets of plain work robes one wand',
#   'Line_number': 207},
#  {'Character': 'Hagrid',
#   'Sentence': 'Essential bit of equipment Harry',
#   'Line_number': 208},
#  {'Character': 'Harry',
#   'Sentence': 'One pair of dragon hide gloves',
#   'Line_number': 209},
#  {'Character': 'Harry',
#   'Sentence': 'Hagrid Do they mean from a real dragon',
#   'Line_number': 210},
#  {'Character': 'Hagrid',
#   'Sentence': 'They dont mean a penguin do they',
#   'Line_number': 211},
#  {'Character': 'Hagrid',
#   'Sentence': 'Crikey Id love a dragon',
#   'Line_number': 212},
#  {'Character': 'Harry', 'Sentence': 'Youd like a dragon', 'Line_number': 213},
#  {'Character': 'Hagrid',
#   'Sentence': 'Vastly misunderstood beasts Harry',
#   'Line_number': 214},
#  {'Character': 'Hagrid',
#   'Sentence': 'Vastly misunderstood',
#   'Line_number': 215},
#  {'Character': 'Harry',
#   'Sentence': 'All students must be equipped with one standard size 2 pewter cauldron and may bring if they desire either an owl a cat or a toad',
#   'Line_number': 216},
#  {'Character': 'Harry',
#   'Sentence': 'Can we find all this in London',
#   'Line_number': 217},
#  {'Character': 'Hagrid',
#   'Sentence': 'If you know where to go',
#   'Line_number': 218},
#  {'Character': 'BarkeepTom',
#   'Sentence': 'Ah Hagrid The usual I presume',
#   'Line_number': 219},
#  {'Character': 'Hagrid', 'Sentence': 'No thanks Tom', 'Line_number': 220},
#  {'Character': 'Hagrid',
#   'Sentence': 'Im on official Hogwarts business',
#   'Line_number': 221},
#  {'Character': 'Hagrid',
#   'Sentence': 'Just helping young Harry here buy his school supplies',
#   'Line_number': 222},
#  {'Character': 'BarkeepTom', 'Sentence': 'Bless my soul', 'Line_number': 223},
#  {'Character': 'BarkeepTom',
#   'Sentence': 'Its Harry Potter',
#   'Line_number': 224},
#  {'Character': 'Man',
#   'Sentence': 'Welcome back Mr Potter',
#   'Line_number': 225},
#  {'Character': 'Man', 'Sentence': 'Welcome back', 'Line_number': 226},
#  {'Character': 'Witch',
#   'Sentence': 'Doris Crockford Mr Potter',
#   'Line_number': 227},
#  {'Character': 'Witch',
#   'Sentence': 'I cant believe Im meeting you at last',
#   'Line_number': 228},
#  {'Character': 'Quirrell',
#   'Sentence': 'Harry Potter Cant tell you how pleased I am to meet you',
#   'Line_number': 229},
#  {'Character': 'Hagrid',
#   'Sentence': 'Hello professor I didnt see you there',
#   'Line_number': 230},
#  {'Character': 'Hagrid',
#   'Sentence': 'Harry This is Professor Quirrell',
#   'Line_number': 231},
#  {'Character': 'Hagrid',
#   'Sentence': 'He will be your Defense Against the Dark Arts teacher at Hogwarts',
#   'Line_number': 232},
#  {'Character': 'Harry', 'Sentence': 'Oh nice to meet you', 'Line_number': 233},
#  {'Character': 'Quirrell',
#   'Sentence': 'Fearfully fascinating subject',
#   'Line_number': 234},
#  {'Character': 'Quirrell',
#   'Sentence': 'Not that you need it eh Potter',
#   'Line_number': 235},
#  {'Character': 'Hagrid',
#   'Sentence': 'Yes well must be going now',
#   'Line_number': 236},
#  {'Character': 'Hagrid', 'Sentence': 'Lots to buy', 'Line_number': 237},
#  {'Character': 'Harry', 'Sentence': 'Goodbye', 'Line_number': 238},
#  {'Character': 'Hagrid',
#   'Sentence': 'See Harry Youre famous',
#   'Line_number': 239},
#  {'Character': 'Harry',
#   'Sentence': 'But why am I famous Hagrid',
#   'Line_number': 240},
#  {'Character': 'Harry',
#   'Sentence': 'All those people back there how is it they know who I am',
#   'Line_number': 241},
#  {'Character': 'Hagrid',
#   'Sentence': 'Im not sure Im exactly the right person to tell you that Harry',
#   'Line_number': 242},
#  {'Character': 'Hagrid',
#   'Sentence': 'Welcome Harry to Diagon Alley',
#   'Line_number': 243},
#  {'Character': 'Hagrid',
#   'Sentence': 'Heres where youll get your quills and your ink',
#   'Line_number': 244},
#  {'Character': 'Hagrid',
#   'Sentence': 'And over there all your bits and bobs for doing your wizardry',
#   'Line_number': 245},
#  {'Character': 'Boy',
#   'Sentence': 'Its a worldclass racing broom',
#   'Line_number': 246},
#  {'Character': 'Boy',
#   'Sentence': 'Look at it The new Nimbus 2000',
#   'Line_number': 247},
#  {'Character': 'Boy',
#   'Sentence': 'Its the fastest model yet',
#   'Line_number': 248},
#  {'Character': 'Harry',
#   'Sentence': 'But Hagrid how am I to pay for all this',
#   'Line_number': 249},
#  {'Character': 'Harry', 'Sentence': 'I havent any money', 'Line_number': 250},
#  {'Character': 'Hagrid',
#   'Sentence': 'Well theres your money Harry',
#   'Line_number': 251},
#  {'Character': 'Hagrid',
#   'Sentence': 'Gringotts the wizard bank',
#   'Line_number': 252},
#  {'Character': 'Hagrid',
#   'Sentence': 'Aint no safer place not one',
#   'Line_number': 253},
#  {'Character': 'Hagrid',
#   'Sentence': 'Except perhaps Hogwarts',
#   'Line_number': 254},
#  {'Character': 'Harry',
#   'Sentence': 'Hagrid what exactly are these things',
#   'Line_number': 255},
#  {'Character': 'Hagrid',
#   'Sentence': 'Theyre goblins Harry',
#   'Line_number': 256},
#  {'Character': 'Hagrid',
#   'Sentence': 'Clever as they come goblins but not the most friendly of beasts',
#   'Line_number': 257},
#  {'Character': 'Hagrid', 'Sentence': 'Best stay close', 'Line_number': 258},
#  {'Character': 'Hagrid',
#   'Sentence': 'Mr Harry Potter wishes to make a withdrawal',
#   'Line_number': 259},
#  {'Character': 'Goblin',
#   'Sentence': 'And does Mr Harry Potter have his key',
#   'Line_number': 260},
#  {'Character': 'Hagrid', 'Sentence': 'Oh Wait a minute', 'Line_number': 261},
#  {'Character': 'Hagrid',
#   'Sentence': 'Got it here somewhere',
#   'Line_number': 262},
#  {'Character': 'Hagrid',
#   'Sentence': 'Ha Heres the little devil',
#   'Line_number': 263},
#  {'Character': 'Hagrid',
#   'Sentence': 'Oh and theres something else as well',
#   'Line_number': 264},
#  {'Character': 'Hagrid',
#   'Sentence': 'Professor Dumbledore gave me this',
#   'Line_number': 265},
#  {'Character': 'Hagrid',
#   'Sentence': 'Its about YouKnowWhat in vault youknowwhich',
#   'Line_number': 266},
#  {'Character': 'Goblin', 'Sentence': 'Very well', 'Line_number': 267},
#  {'Character': 'Griphook', 'Sentence': 'Vault 687', 'Line_number': 268},
#  {'Character': 'Griphook', 'Sentence': 'Lamp please', 'Line_number': 269},
#  {'Character': 'Griphook', 'Sentence': 'Key please', 'Line_number': 270},
#  {'Character': 'Hagrid',
#   'Sentence': 'Didnt think your mum and dad will leave you with nothing now did ya',
#   'Line_number': 271},
#  {'Character': 'Griphook', 'Sentence': 'Vault 713', 'Line_number': 272},
#  {'Character': 'Harry',
#   'Sentence': 'Whats in there Hagrid',
#   'Line_number': 273},
#  {'Character': 'Hagrid',
#   'Sentence': 'Cant tell you Harry',
#   'Line_number': 274},
#  {'Character': 'Hagrid',
#   'Sentence': 'Hogwarts business Very secret',
#   'Line_number': 275},
#  {'Character': 'Griphook', 'Sentence': 'Stand back', 'Line_number': 276},
#  {'Character': 'Hagrid',
#   'Sentence': 'Best not to mention this to anyone Harry',
#   'Line_number': 277},
#  {'Character': 'Harry', 'Sentence': 'I still need a wand', 'Line_number': 278},
#  {'Character': 'Hagrid',
#   'Sentence': 'A wand Well youll want Ollivanders',
#   'Line_number': 279},
#  {'Character': 'Hagrid',
#   'Sentence': 'There aint no place better',
#   'Line_number': 280},
#  {'Character': 'Hagrid',
#   'Sentence': 'Why dont you run along there and wait',
#   'Line_number': 281},
#  {'Character': 'Hagrid',
#   'Sentence': 'I just got one more thing I gotta do',
#   'Line_number': 282},
#  {'Character': 'Hagrid', 'Sentence': 'Wont be long', 'Line_number': 283},
#  {'Character': 'Harry', 'Sentence': 'Hello', 'Line_number': 284},
#  {'Character': 'Harry', 'Sentence': 'Hello', 'Line_number': 285},
#  {'Character': 'Ollivander',
#   'Sentence': 'I wondered when Id be seeing you Mr Potter',
#   'Line_number': 286},
#  {'Character': 'Ollivander',
#   'Sentence': 'It seems only yesterday that your mother and father were in here buying their first wands',
#   'Line_number': 287},
#  {'Character': 'Ollivander', 'Sentence': 'Here we are', 'Line_number': 288},
#  {'Character': 'Ollivander', 'Sentence': 'Give it a wave', 'Line_number': 289},
#  {'Character': 'Ollivander', 'Sentence': 'Apparently not', 'Line_number': 290},
#  {'Character': 'Ollivander', 'Sentence': 'Perhaps this', 'Line_number': 291},
#  {'Character': 'Ollivander',
#   'Sentence': 'No no definitely not',
#   'Line_number': 292},
#  {'Character': 'Ollivander', 'Sentence': 'No matter', 'Line_number': 293},
#  {'Character': 'Ollivander',
#   'Sentence': 'I wonder Curious',
#   'Line_number': 294},
#  {'Character': 'Ollivander', 'Sentence': 'Very curious', 'Line_number': 295},
#  {'Character': 'Harry',
#   'Sentence': 'Sorry but whats curious',
#   'Line_number': 296},
#  {'Character': 'Ollivander',
#   'Sentence': 'I remember every wand Ive ever sold Mr Potter',
#   'Line_number': 297},
#  {'Character': 'Ollivander',
#   'Sentence': 'It so happens that the phoenix whose tail feather resides in your wand gave another feather',
#   'Line_number': 298},
#  {'Character': 'Ollivander', 'Sentence': 'Just one other', 'Line_number': 299},
#  {'Character': 'Ollivander',
#   'Sentence': 'It is curious that you should be destined for this wand when its brother gave you that scar',
#   'Line_number': 300},
#  {'Character': 'Harry',
#   'Sentence': 'And who owned that wand',
#   'Line_number': 301},
#  {'Character': 'Ollivander',
#   'Sentence': 'We do not speak his name',
#   'Line_number': 302},
#  {'Character': 'Ollivander',
#   'Sentence': 'The wand chooses the wizard Mr Potter',
#   'Line_number': 303},
#  {'Character': 'Ollivander',
#   'Sentence': 'Its not always clear why',
#   'Line_number': 304},
#  {'Character': 'Ollivander',
#   'Sentence': 'But I think it is clear that we can expect great things from you',
#   'Line_number': 305},
#  {'Character': 'Ollivander',
#   'Sentence': 'After all HeWhoMustNotBeNamed did great things',
#   'Line_number': 306},
#  {'Character': 'Ollivander',
#   'Sentence': 'Terrible yes but great',
#   'Line_number': 307},
#  {'Character': 'Hagrid', 'Sentence': 'Harry Harry', 'Line_number': 308},
#  {'Character': 'Hagrid', 'Sentence': 'Happy birthday', 'Line_number': 309},
#  {'Character': 'Hagrid',
#   'Sentence': 'You all right Harry',
#   'Line_number': 310},
#  {'Character': 'Hagrid',
#   'Sentence': 'You seem very quiet',
#   'Line_number': 311},
#  {'Character': 'Harry',
#   'Sentence': 'He killed my parents didnt he',
#   'Line_number': 312},
#  {'Character': 'Harry',
#   'Sentence': 'The one who gave me this',
#   'Line_number': 313},
#  {'Character': 'Harry', 'Sentence': 'You know Hagrid', 'Line_number': 314},
#  {'Character': 'Harry', 'Sentence': 'I know you do', 'Line_number': 315},
#  {'Character': 'Hagrid',
#   'Sentence': 'First and understand this Harry because its very important',
#   'Line_number': 316},
#  {'Character': 'Hagrid',
#   'Sentence': 'Not all wizards are good',
#   'Line_number': 317},
#  {'Character': 'Hagrid',
#   'Sentence': 'Some of them go bad',
#   'Line_number': 318},
#  {'Character': 'Hagrid',
#   'Sentence': 'A few years ago there was a one wizard who went as bad as he can go',
#   'Line_number': 319},
#  {'Character': 'Hagrid', 'Sentence': 'His name was V', 'Line_number': 320},
#  {'Character': 'Hagrid', 'Sentence': 'His name was V', 'Line_number': 321},
#  {'Character': 'Harry',
#   'Sentence': 'Maybe if you wrote it down',
#   'Line_number': 322},
#  {'Character': 'Hagrid', 'Sentence': 'No I cant spell it', 'Line_number': 323},
#  {'Character': 'Hagrid',
#   'Sentence': 'All right Voldemort',
#   'Line_number': 324},
#  {'Character': 'Harry', 'Sentence': 'Voldemort', 'Line_number': 325},
#  {'Character': 'Hagrid',
#   'Sentence': 'It was dark times Harry Dark times',
#   'Line_number': 326},
#  {'Character': 'Hagrid',
#   'Sentence': 'Voldemort started to gather some followers',
#   'Line_number': 327},
#  {'Character': 'Hagrid',
#   'Sentence': 'Brought them over to the Dark Side',
#   'Line_number': 328},
#  {'Character': 'Hagrid',
#   'Sentence': 'Anyone that stood up to him ended up dead',
#   'Line_number': 329},
#  {'Character': 'Hagrid',
#   'Sentence': 'Your parents fought against him',
#   'Line_number': 330},
#  {'Character': 'Hagrid',
#   'Sentence': 'But nobody lived once he decided to kill them',
#   'Line_number': 331},
#  {'Character': 'Hagrid', 'Sentence': 'Nobody not one', 'Line_number': 332},
#  {'Character': 'Hagrid', 'Sentence': 'Except you', 'Line_number': 333},
#  {'Character': 'Harry',
#   'Sentence': 'Me Voldemort tried to kill me',
#   'Line_number': 334},
#  {'Character': 'Hagrid',
#   'Sentence': 'Yes That aint no ordinary cut on your forehead Harry',
#   'Line_number': 335},
#  {'Character': 'Hagrid',
#   'Sentence': 'A mark like that only comes from being touched by a curse and an evil curse at that',
#   'Line_number': 336},
#  {'Character': 'Harry', 'Sentence': 'What happened to V', 'Line_number': 337},
#  {'Character': 'Harry', 'Sentence': 'To YouKnowWho', 'Line_number': 338},
#  {'Character': 'Hagrid',
#   'Sentence': 'Well some say he died',
#   'Line_number': 339},
#  {'Character': 'Hagrid',
#   'Sentence': 'Codswallop in my opinion',
#   'Line_number': 340},
#  {'Character': 'Hagrid',
#   'Sentence': 'Nope I reckon hes out there still too tired to carry on',
#   'Line_number': 341},
#  {'Character': 'Hagrid',
#   'Sentence': 'But one things absolutely certain',
#   'Line_number': 342},
#  {'Character': 'Hagrid',
#   'Sentence': 'Something about you stumped him that night',
#   'Line_number': 343},
#  {'Character': 'Hagrid',
#   'Sentence': 'Thats why youre famous',
#   'Line_number': 344},
#  {'Character': 'Hagrid',
#   'Sentence': 'Thats why everybody knows your name',
#   'Line_number': 345},
#  {'Character': 'Hagrid',
#   'Sentence': 'Youre the boy who lived',
#   'Line_number': 346},
#  {'Character': 'Hagrid',
#   'Sentence': 'What are you looking at',
#   'Line_number': 347},
#  {'Character': 'Hagrid',
#   'Sentence': 'Blimey is that the time',
#   'Line_number': 348},
#  {'Character': 'Hagrid',
#   'Sentence': 'Sorry Harry Im gonna have to leave you',
#   'Line_number': 349},
#  {'Character': 'Hagrid',
#   'Sentence': 'Dumbledore will be wanting his',
#   'Line_number': 350},
#  {'Character': 'Hagrid',
#   'Sentence': 'Well hell be wanting to see me',
#   'Line_number': 351},
#  {'Character': 'Hagrid',
#   'Sentence': 'Now uh your train leaves in 10 minutes',
#   'Line_number': 352},
#  {'Character': 'Hagrid', 'Sentence': 'Heres your ticket', 'Line_number': 353},
#  {'Character': 'Hagrid',
#   'Sentence': 'Stick to it Harry thats very important',
#   'Line_number': 354},
#  {'Character': 'Hagrid',
#   'Sentence': 'Stick to your ticket',
#   'Line_number': 355},
#  {'Character': 'Harry', 'Sentence': 'Platform 9 34', 'Line_number': 356},
#  {'Character': 'Harry',
#   'Sentence': 'But Hagrid there must be a mistake',
#   'Line_number': 357},
#  {'Character': 'Harry',
#   'Sentence': 'This says platform 9 34',
#   'Line_number': 358},
#  {'Character': 'Harry',
#   'Sentence': 'Theres no such thing is there',
#   'Line_number': 359},
#  {'Character': 'Man', 'Sentence': 'Sorry', 'Line_number': 360},
#  {'Character': 'Harry', 'Sentence': 'Excuse me Excuse me', 'Line_number': 361},
#  {'Character': 'Trainmaster',
#   'Sentence': 'Right on your left Madam',
#   'Line_number': 362},
#  {'Character': 'Harry',
#   'Sentence': 'Excuse me Sir Can you tell me where I might find platform 9 34',
#   'Line_number': 363},
#  {'Character': 'Trainmaster',
#   'Sentence': '9 34 Think youre being funny do ya',
#   'Line_number': 364},
#  {'Character': 'Mrs Weasley',
#   'Sentence': 'Its the same every year packed with Muggles Of course',
#   'Line_number': 365},
#  {'Character': 'Mrs Weasley', 'Sentence': 'Come on', 'Line_number': 366},
#  {'Character': 'Harry', 'Sentence': 'Muggles', 'Line_number': 367},
#  {'Character': 'Mrs Weasley',
#   'Sentence': 'Platform 9 34 this way',
#   'Line_number': 368},
#  {'Character': 'Mrs Weasley',
#   'Sentence': 'All right Percy you first',
#   'Line_number': 369},
#  {'Character': 'Mrs Weasley', 'Sentence': 'Fred you next', 'Line_number': 370},
#  {'Character': 'George', 'Sentence': 'Hes not Fred I am', 'Line_number': 371},
#  {'Character': 'Fred',
#   'Sentence': 'Honestly woman you call yourself our mother',
#   'Line_number': 372},
#  {'Character': 'Mrs Weasley',
#   'Sentence': 'Oh Im sorry George',
#   'Line_number': 373},
#  {'Character': 'Fred',
#   'Sentence': 'Im only joking I am Fred',
#   'Line_number': 374},
#  {'Character': 'Harry', 'Sentence': 'Excuse me', 'Line_number': 375},
#  {'Character': 'Harry',
#   'Sentence': 'Could you tell me how to',
#   'Line_number': 376},
#  {'Character': 'Mrs Weasley',
#   'Sentence': 'How to get onto the platform',
#   'Line_number': 377},
#  {'Character': 'Mrs Weasley',
#   'Sentence': 'Not to worry dear',
#   'Line_number': 378},
#  {'Character': 'Mrs Weasley',
#   'Sentence': 'Its Rons first time to Hogwarts as well',
#   'Line_number': 379},
#  {'Character': 'Mrs Weasley',
#   'Sentence': 'All youve got do is walk straight at the wall between platforms 9 and 10',
#   'Line_number': 380},
#  {'Character': 'Mrs Weasley',
#   'Sentence': 'Best do it at a bit of a run if youre nervous',
#   'Line_number': 381},
#  {'Character': 'Ginny', 'Sentence': 'Good luck', 'Line_number': 382},
#  {'Character': 'Ron', 'Sentence': 'Excuse me Do you mind', 'Line_number': 383},
#  {'Character': 'Ron',
#   'Sentence': 'Everywhere else is full',
#   'Line_number': 384},
#  {'Character': 'Harry', 'Sentence': 'No Not at all', 'Line_number': 385},
#  {'Character': 'Ron', 'Sentence': 'Im Ron by the way', 'Line_number': 386},
#  {'Character': 'Ron', 'Sentence': 'Ron Weasley', 'Line_number': 387},
#  {'Character': 'Harry',
#   'Sentence': 'Im Harry Harry Potter',
#   'Line_number': 388},
#  {'Character': 'Ron', 'Sentence': 'So its true', 'Line_number': 389},
#  {'Character': 'Ron',
#   'Sentence': 'I mean do you really have the',
#   'Line_number': 390},
#  {'Character': 'Harry', 'Sentence': 'The what', 'Line_number': 391},
#  {'Character': 'Ron', 'Sentence': 'The scar', 'Line_number': 392},
#  {'Character': 'Ron', 'Sentence': 'Wicked', 'Line_number': 393},
#  {'Character': 'Woman',
#   'Sentence': 'Anything off the trolley dears',
#   'Line_number': 394},
#  {'Character': 'Ron', 'Sentence': 'No thanks Im all set', 'Line_number': 395},
#  {'Character': 'Harry', 'Sentence': 'Well take the lot', 'Line_number': 396},
#  {'Character': 'Harry',
#   'Sentence': 'Bertie Botts Every Flavor Beans',
#   'Line_number': 397},
#  {'Character': 'Ron',
#   'Sentence': 'They mean every flavor',
#   'Line_number': 398},
#  {'Character': 'Ron',
#   'Sentence': 'Theres chocolate and peppermint and theres also spinach liver and tripe',
#   'Line_number': 399},
#  {'Character': 'Ron',
#   'Sentence': 'George sweared he got a bogeyflavoured one once',
#   'Line_number': 400},
#  {'Character': 'Harry',
#   'Sentence': 'These arent real frogs are they',
#   'Line_number': 401},
#  {'Character': 'Ron', 'Sentence': 'Its just a spell', 'Line_number': 402},
#  {'Character': 'Ron',
#   'Sentence': 'Besides Its the cards you want',
#   'Line_number': 403},
#  {'Character': 'Ron',
#   'Sentence': 'Each packs got a famous witch or wizard',
#   'Line_number': 404},
#  {'Character': 'Ron',
#   'Sentence': 'Ive got about 500 myself',
#   'Line_number': 405},
#  {'Character': 'Ron', 'Sentence': 'Watch it', 'Line_number': 406},
#  {'Character': 'Ron', 'Sentence': 'Oh thats rotten luck', 'Line_number': 407},
#  {'Character': 'Ron',
#   'Sentence': 'Theyve only got one good jump in them to begin with',
#   'Line_number': 408},
#  {'Character': 'Harry', 'Sentence': 'Ive got Dumbledore', 'Line_number': 409},
#  {'Character': 'Ron',
#   'Sentence': 'I got about six of him',
#   'Line_number': 410},
#  {'Character': 'Harry', 'Sentence': 'Hey hes gone', 'Line_number': 411},
#  {'Character': 'Ron',
#   'Sentence': 'Well you cant expect him to hang around all day can you',
#   'Line_number': 412},
#  {'Character': 'Ron',
#   'Sentence': 'This is Scabbers by the way',
#   'Line_number': 413},
#  {'Character': 'Ron', 'Sentence': 'Pathetic isnt he', 'Line_number': 414},
#  {'Character': 'Harry', 'Sentence': 'Just a little bit', 'Line_number': 415},
#  {'Character': 'Ron',
#   'Sentence': 'Fred gave me a spell as to turn him yellow',
#   'Line_number': 416},
#  {'Character': 'Ron', 'Sentence': 'Want to see', 'Line_number': 417},
#  {'Character': 'Harry', 'Sentence': 'Yeah', 'Line_number': 418},
#  {'Character': 'Hermione',
#   'Sentence': 'Has anyone seen a toad',
#   'Line_number': 419},
#  {'Character': 'Hermione',
#   'Sentence': 'A boy named Nevilles lost one',
#   'Line_number': 420},
#  {'Character': 'Ron', 'Sentence': 'No', 'Line_number': 421},
#  {'Character': 'Hermione',
#   'Sentence': 'Oh are you doing magic',
#   'Line_number': 422},
#  {'Character': 'Hermione', 'Sentence': 'Lets see then', 'Line_number': 423},
#  {'Character': 'Ron',
#   'Sentence': 'Sunshine daisies butter mellow',
#   'Line_number': 424},
#  {'Character': 'Ron',
#   'Sentence': 'Turn this stupid fat rat yellow',
#   'Line_number': 425},
#  {'Character': 'Hermione',
#   'Sentence': 'Are you sure thats a real spell',
#   'Line_number': 426},
#  {'Character': 'Hermione',
#   'Sentence': 'Well its not very good is it',
#   'Line_number': 427},
#  {'Character': 'Hermione',
#   'Sentence': 'Of course Ive only tried a few simple ones myself but theyve all worked for me',
#   'Line_number': 428},
#  {'Character': 'Hermione', 'Sentence': 'For example', 'Line_number': 429},
#  {'Character': 'Hermione', 'Sentence': 'Oculus Reparo', 'Line_number': 430},
#  {'Character': 'Hermione',
#   'Sentence': 'Thats better isnt it',
#   'Line_number': 431},
#  {'Character': 'Hermione',
#   'Sentence': 'Holy cricket youre Harry Potter',
#   'Line_number': 432},
#  {'Character': 'Hermione',
#   'Sentence': 'Im Hermione Granger',
#   'Line_number': 433},
#  {'Character': 'Hermione', 'Sentence': 'And you are', 'Line_number': 434},
#  {'Character': 'Ron', 'Sentence': 'Im Ron Weasley', 'Line_number': 435},
#  {'Character': 'Hermione', 'Sentence': 'Pleasure', 'Line_number': 436},
#  {'Character': 'Hermione',
#   'Sentence': 'You two better change into robes',
#   'Line_number': 437},
#  {'Character': 'Hermione',
#   'Sentence': 'I expect well be arriving soon',
#   'Line_number': 438},
#  {'Character': 'Hermione',
#   'Sentence': 'Youve got dirt on your nose by the way',
#   'Line_number': 439},
#  {'Character': 'Hermione', 'Sentence': 'Did you know', 'Line_number': 440},
#  {'Character': 'Hermione', 'Sentence': 'Just there', 'Line_number': 441},
#  {'Character': 'Hagrid', 'Sentence': 'Right then', 'Line_number': 442},
#  {'Character': 'Hagrid',
#   'Sentence': 'First years this way please',
#   'Line_number': 443},
#  {'Character': 'Hagrid',
#   'Sentence': 'Come on now first years dont be shy',
#   'Line_number': 444},
#  {'Character': 'Hagrid',
#   'Sentence': 'Come on now hurry up',
#   'Line_number': 445},
#  {'Character': 'Hagrid', 'Sentence': 'Hello Harry', 'Line_number': 446},
#  {'Character': 'Harry', 'Sentence': 'Hey Hagrid', 'Line_number': 447},
#  {'Character': 'Hagrid',
#   'Sentence': 'Right then This way to the boats',
#   'Line_number': 448},
#  {'Character': 'Hagrid',
#   'Sentence': 'Come on now follow me',
#   'Line_number': 449},
#  {'Character': 'Ron', 'Sentence': 'Wicked', 'Line_number': 450},
#  {'Character': 'McGonagall',
#   'Sentence': 'Welcome to Hogwarts',
#   'Line_number': 451},
#  {'Character': 'McGonagall',
#   'Sentence': 'Now in a few moments youll pass through these doors and join your classmates',
#   'Line_number': 452},
#  {'Character': 'McGonagall',
#   'Sentence': 'But before you can take your seats you must be sorted into your houses',
#   'Line_number': 453},
#  {'Character': 'McGonagall',
#   'Sentence': 'They are Gryffindor Hufflepuff Ravenclaw and Slytherin',
#   'Line_number': 454},
#  {'Character': 'McGonagall',
#   'Sentence': 'Now while youre here your house will be like your family',
#   'Line_number': 455},
#  {'Character': 'McGonagall',
#   'Sentence': 'Your triumphs will earn you points',
#   'Line_number': 456},
#  {'Character': 'McGonagall',
#   'Sentence': 'Any rulebreaking and you will lose points',
#   'Line_number': 457},
#  {'Character': 'McGonagall',
#   'Sentence': 'At the end of the year the house with the most points is awarded the house cup',
#   'Line_number': 458},
#  {'Character': 'Neville', 'Sentence': 'Trevor Sorry', 'Line_number': 459},
#  {'Character': 'McGonagall',
#   'Sentence': 'The Sorting Ceremony will begin momentarily',
#   'Line_number': 460},
#  {'Character': 'Malfoy',
#   'Sentence': 'Its true then what theyre saying on the train',
#   'Line_number': 461},
#  {'Character': 'Malfoy',
#   'Sentence': 'Harry Potter has come to Hogwarts',
#   'Line_number': 462},
#  {'Character': 'Whispers', 'Sentence': 'Harry Potter', 'Line_number': 463},
#  {'Character': 'Malfoy',
#   'Sentence': 'This is Crabbe and Goyle',
#   'Line_number': 464},
#  {'Character': 'Malfoy', 'Sentence': 'And Im Malfoy', 'Line_number': 465},
#  {'Character': 'Malfoy', 'Sentence': 'Draco Malfoy', 'Line_number': 466},
#  {'Character': 'Malfoy',
#   'Sentence': 'Think my names funny do you',
#   'Line_number': 467},
#  {'Character': 'Malfoy',
#   'Sentence': 'Ive no need to ask yours',
#   'Line_number': 468},
#  {'Character': 'Malfoy',
#   'Sentence': 'Red hair and a handmedown robe',
#   'Line_number': 469},
#  {'Character': 'Malfoy',
#   'Sentence': 'You must be a Weasley',
#   'Line_number': 470},
#  {'Character': 'Malfoy',
#   'Sentence': 'Well soon find out that some wizarding families are better than others Potter',
#   'Line_number': 471},
#  {'Character': 'Malfoy',
#   'Sentence': 'You dont want to go making friends with the wrong sort',
#   'Line_number': 472},
#  {'Character': 'Malfoy',
#   'Sentence': 'I can help you there',
#   'Line_number': 473},
#  {'Character': 'Harry',
#   'Sentence': 'I think I can tell the wrong sort for myself thanks',
#   'Line_number': 474},
#  {'Character': 'McGonagall',
#   'Sentence': 'Were ready for you now',
#   'Line_number': 475},
#  {'Character': 'McGonagall', 'Sentence': 'Follow me', 'Line_number': 476},
#  {'Character': 'Hermione',
#   'Sentence': 'Its not real the ceiling',
#   'Line_number': 477},
#  {'Character': 'Hermione',
#   'Sentence': 'Its just bewitched to look like the night sky',
#   'Line_number': 478},
#  {'Character': 'Hermione',
#   'Sentence': 'I read about it in Hogwarts A History',
#   'Line_number': 479},
#  {'Character': 'McGonagall',
#   'Sentence': 'All right will you wait along here please',
#   'Line_number': 480},
#  {'Character': 'McGonagall',
#   'Sentence': 'Now before we begin Professor Dumbledore would like to say a few words',
#   'Line_number': 481},
#  {'Character': 'Dumbledore',
#   'Sentence': 'I have a few startofterm notices I wish to announce',
#   'Line_number': 482},
#  {'Character': 'Dumbledore',
#   'Sentence': 'The first years please note that the Dark Forest is strictly forbidden to all students',
#   'Line_number': 483},
#  {'Character': 'Dumbledore',
#   'Sentence': 'Also our caretaker Mr Filch has asked me to remind you that the thirdfloor corridor on the right hand side is out of bounds to everyone who does not wish to die a most painful death',
#   'Line_number': 484},
#  {'Character': 'Dumbledore', 'Sentence': 'Thank you', 'Line_number': 485},
#  {'Character': 'McGonagall',
#   'Sentence': 'When I call your name you will come forth',
#   'Line_number': 486},
#  {'Character': 'McGonagall',
#   'Sentence': 'I shall place the Sorting Hat on your head and you will be sorted into your houses',
#   'Line_number': 487},
#  {'Character': 'McGonagall',
#   'Sentence': 'Hermione Granger',
#   'Line_number': 488},
#  {'Character': 'Hermione', 'Sentence': 'Oh no Okay relax', 'Line_number': 489},
#  {'Character': 'Ron',
#   'Sentence': 'Mental that one Im telling you',
#   'Line_number': 490},
#  {'Character': 'Sorting Hat',
#   'Sentence': 'Ah right then hmm right',
#   'Line_number': 491},
#  {'Character': 'Sorting Hat',
#   'Sentence': 'Okay Gryffindor',
#   'Line_number': 492},
#  {'Character': 'McGonagall', 'Sentence': 'Draco Malfoy', 'Line_number': 493},
#  {'Character': 'Sorting Hat', 'Sentence': 'Slytherin', 'Line_number': 494},
#  {'Character': 'Ron',
#   'Sentence': 'There isnt a witch or wizard who went bad who wasnt in Slytherin',
#   'Line_number': 495},
#  {'Character': 'McGonagall', 'Sentence': 'Susan Bones', 'Line_number': 496},
#  {'Character': 'Ron', 'Sentence': 'Harry what is it', 'Line_number': 497},
#  {'Character': 'Harry',
#   'Sentence': 'Nothing Nothing Im fine',
#   'Line_number': 498},
#  {'Character': 'Sorting Hat',
#   'Sentence': 'Lets see I know Hufflepuff',
#   'Line_number': 499},
#  {'Character': 'McGonagall', 'Sentence': 'Ronald Weasley', 'Line_number': 500},
#  {'Character': 'Sorting Hat',
#   'Sentence': 'Another Weasley',
#   'Line_number': 501},
#  {'Character': 'Sorting Hat',
#   'Sentence': 'I know just what to do with you',
#   'Line_number': 502},
#  {'Character': 'Sorting Hat', 'Sentence': 'Gryffindor', 'Line_number': 503},
#  {'Character': 'McGonagall', 'Sentence': 'Harry Potter', 'Line_number': 504},
#  {'Character': 'Sorting Hat',
#   'Sentence': 'Hmm difficult very difficult',
#   'Line_number': 505},
#  {'Character': 'Sorting Hat',
#   'Sentence': 'Plenty of courage I see',
#   'Line_number': 506},
#  {'Character': 'Sorting Hat',
#   'Sentence': 'Not a bad mind either',
#   'Line_number': 507},
#  {'Character': 'Sorting Hat',
#   'Sentence': 'Theres talent oh yes',
#   'Line_number': 508},
#  {'Character': 'Sorting Hat',
#   'Sentence': 'And a thirst to prove yourself',
#   'Line_number': 509},
#  {'Character': 'Sorting Hat',
#   'Sentence': 'But where to put you',
#   'Line_number': 510},
#  {'Character': 'Harry',
# ...
#  {'Character': 'Harry', 'Sentence': 'Do something', 'Line_number': 826},
#  {'Character': 'Ron', 'Sentence': 'What', 'Line_number': 827},
#  {'Character': 'Harry', 'Sentence': 'Anything', 'Line_number': 828},
#  {'Character': 'Harry', 'Sentence': 'Hurry up', 'Line_number': 829},
#  {'Character': 'Hermione', 'Sentence': 'Swish and flick', 'Line_number': 830},
#  {'Character': 'Ron', 'Sentence': 'Wingardium Leviosa', 'Line_number': 831},
#  {'Character': 'Ron', 'Sentence': 'Cool', 'Line_number': 832},
#  {'Character': 'Hermione', 'Sentence': 'Is itdead', 'Line_number': 833},
#  {'Character': 'Harry', 'Sentence': 'I dont think so', 'Line_number': 834},
#  {'Character': 'Harry', 'Sentence': 'Just knocked out', 'Line_number': 835},
#  {'Character': 'Harry', 'Sentence': 'Ew Troll bogies', 'Line_number': 836},
#  {'Character': 'McGonagall',
#   'Sentence': 'Oh Oh my goodness',
#   'Line_number': 837},
#  {'Character': 'McGonagall',
#   'Sentence': 'EExplain yourselves both of you',
#   'Line_number': 838},
#  {'Character': 'Ron and Harry',
#   'Sentence': 'Well what it is',
#   'Line_number': 839},
#  {'Character': 'Hermione',
#   'Sentence': 'Its my fault Professor McGonagall',
#   'Line_number': 840},
#  {'Character': 'McGonagall', 'Sentence': 'Ms Granger', 'Line_number': 841},
#  {'Character': 'Hermione',
#   'Sentence': 'I went looking for the troll',
#   'Line_number': 842},
#  {'Character': 'Hermione',
#   'Sentence': 'Id read about them and thought I could handle it',
#   'Line_number': 843},
#  {'Character': 'Hermione', 'Sentence': 'But I was wrong', 'Line_number': 844},
#  {'Character': 'Hermione',
#   'Sentence': 'If Harry and Ron hadnt come and found me',
#   'Line_number': 845},
#  {'Character': 'Hermione',
#   'Sentence': 'Id probably be dead',
#   'Line_number': 846},
#  {'Character': 'McGonagall',
#   'Sentence': 'Be that as it mayit was an extremely foolish thing to do',
#   'Line_number': 847},
#  {'Character': 'McGonagall',
#   'Sentence': 'I would have expected more rational behaviour on your part and I am very disappointed in you Ms Granger',
#   'Line_number': 848},
#  {'Character': 'McGonagall',
#   'Sentence': '5 points will be taken from Gryffindor for your serious lack of judgment',
#   'Line_number': 849},
#  {'Character': 'McGonagall',
#   'Sentence': 'As for you two gentlemen I just hope you realize how fortunate you are',
#   'Line_number': 850},
#  {'Character': 'McGonagall',
#   'Sentence': 'Not many first year students could take on a full grown mountain troll and live to tell the tale',
#   'Line_number': 851},
#  {'Character': 'McGonagall',
#   'Sentence': '5 pointswill be awarded to each of you',
#   'Line_number': 852},
#  {'Character': 'McGonagall',
#   'Sentence': 'For sheer dumb luck',
#   'Line_number': 853},
#  {'Character': 'Quirrell',
#   'Sentence': 'Perhaps you ought to go',
#   'Line_number': 854},
#  {'Character': 'Quirrell',
#   'Sentence': 'Mmight wake uphehAhh Hehe',
#   'Line_number': 855},
#  {'Character': 'Harry',
#   'Sentence': 'Good of you to get us out of trouble like that',
#   'Line_number': 856},
#  {'Character': 'Ron',
#   'Sentence': 'Mind you we did save her life',
#   'Line_number': 857},
#  {'Character': 'Harry',
#   'Sentence': 'Mind you she might not have needed saving if you hadnt insulted her',
#   'Line_number': 858},
#  {'Character': 'Ron', 'Sentence': 'What are friends for', 'Line_number': 859},
#  {'Character': 'Ron',
#   'Sentence': 'Take a bit of toast mate Go on',
#   'Line_number': 860},
#  {'Character': 'Hermione', 'Sentence': 'Rons right Harry', 'Line_number': 861},
#  {'Character': 'Hermione',
#   'Sentence': 'Youre gonna need your strength today',
#   'Line_number': 862},
#  {'Character': 'Harry', 'Sentence': 'Im not hungry', 'Line_number': 863},
#  {'Character': 'Snape',
#   'Sentence': 'Good luck today Potter',
#   'Line_number': 864},
#  {'Character': 'Snape',
#   'Sentence': 'Then again now that youve proven yourself against a troll a little game of Quidditch should be easy work for youeven if it is against Slytherin',
#   'Line_number': 865},
#  {'Character': 'Harry',
#   'Sentence': 'That explains the blood',
#   'Line_number': 866},
#  {'Character': 'Hermione', 'Sentence': 'Blood', 'Line_number': 867},
#  {'Character': 'Harry',
#   'Sentence': 'Listen last night Im guessing Snape let the troll in as a diversion so he could try and get past that 3 headed dog',
#   'Line_number': 868},
#  {'Character': 'Harry',
#   'Sentence': 'But he got himself bitten thats why hes limping',
#   'Line_number': 869},
#  {'Character': 'Hermione',
#   'Sentence': 'But why would anyone go near that dog',
#   'Line_number': 870},
#  {'Character': 'Harry',
#   'Sentence': 'The day I was at Gringotts Hagrid took something out of one of the vaults',
#   'Line_number': 871},
#  {'Character': 'Harry',
#   'Sentence': 'He said it was Hogwarts business very secret',
#   'Line_number': 872},
#  {'Character': 'Hermione', 'Sentence': 'So youre saying', 'Line_number': 873},
#  {'Character': 'Harry',
#   'Sentence': 'Thats what the dogs guarding',
#   'Line_number': 874},
#  {'Character': 'Harry',
#   'Sentence': 'Thats what Snape wants',
#   'Line_number': 875},
#  {'Character': 'Hermione',
#   'Sentence': 'Bit early for mail isnt it',
#   'Line_number': 876},
#  {'Character': 'Harry',
#   'Sentence': 'But II never get mail',
#   'Line_number': 877},
#  {'Character': 'Ron', 'Sentence': 'Lets open it', 'Line_number': 878},
#  {'Character': 'Harry', 'Sentence': 'Its a broomstick', 'Line_number': 879},
#  {'Character': 'Ron',
#   'Sentence': 'Thats not just a broomstick Harry',
#   'Line_number': 880},
#  {'Character': 'Ron', 'Sentence': 'Its a Nimbus 2000', 'Line_number': 881},
#  {'Character': 'Harry', 'Sentence': 'But who', 'Line_number': 882},
#  {'Character': 'OIiver', 'Sentence': 'Scared Harry', 'Line_number': 883},
#  {'Character': 'Harry', 'Sentence': 'A little', 'Line_number': 884},
#  {'Character': 'Oliver', 'Sentence': 'Thats all right', 'Line_number': 885},
#  {'Character': 'Oliver',
#   'Sentence': 'I felt the same way before my first game',
#   'Line_number': 886},
#  {'Character': 'Harry', 'Sentence': 'What happened', 'Line_number': 887},
#  {'Character': 'Oliver',
#   'Sentence': 'Er I dont really remember',
#   'Line_number': 888},
#  {'Character': 'Oliver',
#   'Sentence': 'I took a bludger to the head 2 minutes in',
#   'Line_number': 889},
#  {'Character': 'Oliver',
#   'Sentence': 'Woke up in the hospital a week later',
#   'Line_number': 890},
#  {'Character': 'Lee Jordan',
#   'Sentence': 'Hello and welcome to Hogwarts first Quidditch game of the season',
#   'Line_number': 891},
#  {'Character': 'Lee Jordan',
#   'Sentence': 'Todays game Slytherin versus Gryffindor',
#   'Line_number': 892},
#  {'Character': 'Lee Jordan',
#   'Sentence': 'The players take their positions as Madam Hooch steps out onto the field to begin the game',
#   'Line_number': 893},
#  {'Character': 'Madam Hooch',
#   'Sentence': 'Now I want a nice clean gamefrom all of you',
#   'Line_number': 894},
#  {'Character': 'Lee Jordan',
#   'Sentence': 'The bludgers are upfollowed by the Golden Snitch',
#   'Line_number': 895},
#  {'Character': 'Lee Jordan',
#   'Sentence': 'Remember the snitch is worth 150 points',
#   'Line_number': 896},
#  {'Character': 'Lee Jordan',
#   'Sentence': 'The seeker who catches the Snitch ends the game',
#   'Line_number': 897},
#  {'Character': 'Lee Jordan',
#   'Sentence': 'The Quaffle is releasedand the game begins',
#   'Line_number': 898},
#  {'Character': 'Lee Jordan',
#   'Sentence': 'Angelina Johnson scores',
#   'Line_number': 899},
#  {'Character': 'Lee Jordan',
#   'Sentence': '10 points for Gryffindor',
#   'Line_number': 900},
#  {'Character': 'Harry', 'Sentence': 'Yes Whoa', 'Line_number': 901},
#  {'Character': 'Hagrid', 'Sentence': 'Well done', 'Line_number': 902},
#  {'Character': 'Lee Jordan',
#   'Sentence': 'Slytherin takes possession of the Quaffle',
#   'Line_number': 903},
#  {'Character': 'Lee Jordan',
#   'Sentence': 'Bletchley passes to Captain Marcus Flint',
#   'Line_number': 904},
#  {'Character': 'Harry', 'Sentence': 'Yes', 'Line_number': 905},
#  {'Character': 'Lee Jordan',
#   'Sentence': 'Another 10 points to Gryffindor',
#   'Line_number': 906},
#  {'Character': 'Gryffindors', 'Sentence': 'Yay', 'Line_number': 907},
#  {'Character': 'Flint', 'Sentence': 'Give me that', 'Line_number': 908},
#  {'Character': 'Crowd', 'Sentence': 'Boooo', 'Line_number': 909},
#  {'Character': 'Flint', 'Sentence': 'Take that side', 'Line_number': 910},
#  {'Character': 'Harry', 'Sentence': 'Whoa Whooa', 'Line_number': 911},
#  {'Character': 'Hagrid',
#   'Sentence': 'Whats going on with Harrys broomstick',
#   'Line_number': 912},
#  {'Character': 'Hermione', 'Sentence': 'Its Snape', 'Line_number': 913},
#  {'Character': 'Hermione',
#   'Sentence': 'Hes jinxing the broom',
#   'Line_number': 914},
#  {'Character': 'Ron', 'Sentence': 'Jinxing the broom', 'Line_number': 915},
#  {'Character': 'Ron', 'Sentence': 'What do we do', 'Line_number': 916},
#  {'Character': 'Hermione', 'Sentence': 'Leave it to me', 'Line_number': 917},
#  {'Character': 'Ron', 'Sentence': 'Come on Hermione', 'Line_number': 918},
#  {'Character': 'Hermione',
#   'Sentence': 'Lacarnum Inflamarae',
#   'Line_number': 919},
#  {'Character': 'Man', 'Sentence': 'Fire Youre on fire', 'Line_number': 920},
#  {'Character': 'Snape', 'Sentence': 'What Oh', 'Line_number': 921},
#  {'Character': 'Ron', 'Sentence': 'Go', 'Line_number': 922},
#  {'Character': 'Hagrid', 'Sentence': 'Go go go', 'Line_number': 923},
#  {'Character': 'Hagrid',
#   'Sentence': 'Looks like hes gonna be sick',
#   'Line_number': 924},
#  {'Character': 'Lee  Jordan',
#   'Sentence': 'Hes got the Snitch',
#   'Line_number': 925},
#  {'Character': 'Lee  Jordan',
#   'Sentence': 'Harry Potter receives 150 points for catching the Snitch',
#   'Line_number': 926},
#  {'Character': 'Madam Hooch',
#   'Sentence': 'Gryffindor win',
#   'Line_number': 927},
#  {'Character': 'All', 'Sentence': 'YAY', 'Line_number': 928},
#  {'Character': 'Draco', 'Sentence': 'No', 'Line_number': 929},
#  {'Character': 'Hagrid', 'Sentence': 'Yes', 'Line_number': 930},
#  {'Character': 'Hermione', 'Sentence': 'Whoohoo', 'Line_number': 931},
#  {'Character': 'Crowd',
#   'Sentence': 'Go go Gryffindor Go go Gryffindor',
#   'Line_number': 932},
#  {'Character': 'Hagrid', 'Sentence': 'Nonsense', 'Line_number': 933},
#  {'Character': 'Hagrid',
#   'Sentence': 'Why would Snape put a curse on Harrys broom',
#   'Line_number': 934},
#  {'Character': 'Harry', 'Sentence': 'Who knows', 'Line_number': 935},
#  {'Character': 'Harry',
#   'Sentence': 'Why was he trying to get past that 3 headed dog on Halloween',
#   'Line_number': 936},
#  {'Character': 'Hagrid',
#   'Sentence': 'Who told you bout Fluffy',
#   'Line_number': 937},
#  {'Character': 'Ron', 'Sentence': 'Fluffy', 'Line_number': 938},
#  {'Character': 'Hermione',
#   'Sentence': 'That thing has a name',
#   'Line_number': 939},
#  {'Character': 'Hagrid',
#   'Sentence': 'Well of course hes got a name',
#   'Line_number': 940},
#  {'Character': 'Hagrid', 'Sentence': 'Hes mine', 'Line_number': 941},
#  {'Character': 'Hagrid',
#   'Sentence': 'I bought him off an Irish feller I met down at the pub last year',
#   'Line_number': 942},
#  {'Character': 'Hagrid',
#   'Sentence': 'Then I lent him to Dumbledore to guard the',
#   'Line_number': 943},
#  {'Character': 'Harry', 'Sentence': 'Yes', 'Line_number': 944},
#  {'Character': 'Hagrid',
#   'Sentence': 'Shouldnta said that  No more questions',
#   'Line_number': 945},
#  {'Character': 'Hagrid',
#   'Sentence': 'Dont ask any more questions',
#   'Line_number': 946},
#  {'Character': 'Hagrid',
#   'Sentence': 'Thats top secret that is',
#   'Line_number': 947},
#  {'Character': 'Harry',
#   'Sentence': 'But Hagrid whatever Fluffys guarding Snapes trying to steal it',
#   'Line_number': 948},
#  {'Character': 'Hagrid', 'Sentence': 'Codswallop', 'Line_number': 949},
#  {'Character': 'Hagrid',
#   'Sentence': 'Professor Snape is a Hogwarts teacher',
#   'Line_number': 950},
#  {'Character': 'Hermione',
#   'Sentence': 'Hogwarts teacher or not I know a curse when I see one',
#   'Line_number': 951},
#  {'Character': 'Hermione',
#   'Sentence': 'Ive read all about them',
#   'Line_number': 952},
#  {'Character': 'Hermione',
#   'Sentence': 'You have to keep eye contact',
#   'Line_number': 953},
#  {'Character': 'Hermione',
#   'Sentence': 'And Snape wasnt blinking',
#   'Line_number': 954},
#  {'Character': 'Harry', 'Sentence': 'Exactly', 'Line_number': 955},
#  {'Character': 'Hagrid',
#   'Sentence': 'Now you listen to me all three of you',
#   'Line_number': 956},
#  {'Character': 'Hagrid',
#   'Sentence': 'Youre meddlin in things that ought not to be meddled in',
#   'Line_number': 957},
#  {'Character': 'Hagrid', 'Sentence': 'Its dangerous', 'Line_number': 958},
#  {'Character': 'Hagrid',
#   'Sentence': 'What that dog is guarding is strictly between Professor Dumbledore and Nicholas Flamel',
#   'Line_number': 959},
#  {'Character': 'Harry', 'Sentence': 'Nicholas Flamel', 'Line_number': 960},
#  {'Character': 'Hagrid',
#   'Sentence': 'I shouldnt have said that',
#   'Line_number': 961},
#  {'Character': 'Hagrid',
#   'Sentence': 'I should not have said that',
#   'Line_number': 962},
#  {'Character': 'Hagrid',
#   'Sentence': 'I should not have said that',
#   'Line_number': 963},
#  {'Character': 'Harry',
#   'Sentence': 'Nicholas FlamelWhos Nicholas Flamel',
#   'Line_number': 964},
#  {'Character': 'Hermione', 'Sentence': 'I dont know', 'Line_number': 965},
#  {'Character': 'Harry', 'Sentence': 'Knight to E5', 'Line_number': 966},
#  {'Character': 'Ron', 'Sentence': 'Queen to E5', 'Line_number': 967},
#  {'Character': 'Hermione',
#   'Sentence': 'Thats totally barbaric',
#   'Line_number': 968},
#  {'Character': 'Ron', 'Sentence': 'Thats wizards chess', 'Line_number': 969},
#  {'Character': 'Ron', 'Sentence': 'I see youve packed', 'Line_number': 970},
#  {'Character': 'Hermione', 'Sentence': 'See you havent', 'Line_number': 971},
#  {'Character': 'Ron', 'Sentence': 'Change of plans', 'Line_number': 972},
#  {'Character': 'Ron',
#   'Sentence': 'My parents decided to go to Romania to visit my brother Charlie',
#   'Line_number': 973},
#  {'Character': 'Ron',
#   'Sentence': 'Hes studying dragons there',
#   'Line_number': 974},
#  {'Character': 'Hermione',
#   'Sentence': 'Good You can help Harry then',
#   'Line_number': 975},
#  {'Character': 'Hermione',
#   'Sentence': 'Hes going to go the library for information on Nicholas Flamel',
#   'Line_number': 976},
#  {'Character': 'Ron',
#   'Sentence': 'Weve looked a hundred times',
#   'Line_number': 977},
#  {'Character': 'Hermione',
#   'Sentence': 'Not in the restricted section',
#   'Line_number': 978},
#  {'Character': 'Hermione', 'Sentence': 'Happy Christmas', 'Line_number': 979},
#  {'Character': 'Ron',
#   'Sentence': 'I think weve had a bad influence on her',
#   'Line_number': 980},
#  {'Character': 'Ron', 'Sentence': 'Harry wake up', 'Line_number': 981},
#  {'Character': 'Ron', 'Sentence': 'Come on Harry wake up', 'Line_number': 982},
#  {'Character': 'Ron', 'Sentence': 'Happy Christmas Harry', 'Line_number': 983},
#  {'Character': 'Harry', 'Sentence': 'Happy Christmas Ron', 'Line_number': 984},
#  {'Character': 'Harry',
#   'Sentence': 'What are you wearing',
#   'Line_number': 985},
#  {'Character': 'Ron', 'Sentence': 'Oh Mum made it', 'Line_number': 986},
#  {'Character': 'Ron',
#   'Sentence': 'Looks like youve got one too',
#   'Line_number': 987},
#  {'Character': 'Harry', 'Sentence': 'Ive got presents', 'Line_number': 988},
#  {'Character': 'Ron', 'Sentence': 'Yeah', 'Line_number': 989},
#  {'Character': 'Harry', 'Sentence': 'Oh', 'Line_number': 990},
#  {'Character': 'Ron', 'Sentence': 'There they are', 'Line_number': 991},
#  {'Character': 'Harry',
#   'Sentence': 'Your father left this in my possession before he died',
#   'Line_number': 992},
#  {'Character': 'Harry',
#   'Sentence': 'It is time it was returned to you',
#   'Line_number': 993},
#  {'Character': 'Harry', 'Sentence': 'Use it well', 'Line_number': 994},
#  {'Character': 'Ron', 'Sentence': 'What is it', 'Line_number': 995},
#  {'Character': 'Harry', 'Sentence': 'Some kind ofcloak', 'Line_number': 996},
#  {'Character': 'Ron', 'Sentence': 'Well lets see then', 'Line_number': 997},
#  {'Character': 'Ron', 'Sentence': 'Put it on', 'Line_number': 998},
#  {'Character': 'Ron', 'Sentence': 'Whoa', 'Line_number': 999},
#  ...]

# %% [markdown]
# ## Importing the books

# %%
hp_books = pd.read_csv("data/Harry_Potter_all_books_preprocessed.txt", sep=".", header=None)
hp_books = hp_books.T

# %%
hp_books.rename(columns = {0:'Sentence'}, inplace = True)

docs = hp_books.to_json(orient = "records")
hp_books = loads(docs)

hp_books[0:5]
# Out:
# [{'Sentence': 'THE BOY WHO LIVED Mr and Mrs Dursley of number four Privet Drive were proud to say that they were perfectly normal thank you very much '},
#  {'Sentence': 'They were the last people youd expect to be involved in anything strange or mysterious because they just didnt hold with such nonsense '},
#  {'Sentence': 'Mr Dursley was the director of a firm called Grunnings which made drills '},
#  {'Sentence': 'He was a big beefy man with hardly any neck although he did have a very large mustache '},
#  {'Sentence': 'Mrs Dursley was thin and blonde and had nearly twice the usual amount of neck which came in very useful as she spent so much of her time craning over garden fences spying on the neighbors '}]

# %%
index = "hp_books"
settings = {}
mappings = {
    "_meta" : {
        "created_by" : "Iulia Feroli"
    },
    "properties" : {
        "Sentence" : {
            "type" : "text"
        }
    }
}

client.indices.create(index=index, settings=settings, mappings=mappings)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'hp_books'})

# %%
response = bulk(client = client, index = index, actions = iter(hp_books), stats_only = True )

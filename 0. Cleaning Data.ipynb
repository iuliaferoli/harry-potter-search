# %% [markdown]
# ## 0. Cleaning Data
#
# The dataset we will use in this project is a Harry Potter characters table. This has been created on Kaggle, [see original link here.](https://www.kaggle.com/datasets/gulsahdemiryurek/harry-potter-dataset).
# The author notes "The other data were collected from pottermore.com and https://harrypotter.fandom.com/wiki/Main_Page"
#
# You can either get the data from the Kaggle link or from the data folder in this repo, and use the notebook steps bellow to clean it; or you can directly use the clean_data.csv file and continue to the Elastic Steps in the tutorial here:
#
# [1. Kibana Dashboard](/1.%20Kibana%20Dashboard.md)

# %%
import pandas as pd
import re
hp_data = pd.read_csv("data/Characters.csv", sep = ";" )

# %% [markdown]
# We will first import our data into a pandas dataframe and take a look at what changes need to be made.

# %%
hp_data
# Out:
#       Id                                     Name  Gender  \
# 0      1                       Harry James Potter    Male
# 1      2                    Ronald Bilius Weasley    Male
# 2      3                    Hermione Jean Granger  Female
# 3      4  Albus Percival Wulfric Brian Dumbledore    Male
# 4      5                            Rubeus Hagrid    Male
# ..   ...                                      ...     ...
# 135  136                 Wilhelmina Grubbly-Plank  Female
# 136  137                          Fenrir Greyback    Male
# 137  138                      Gellert Grindelwald    Male
# 138  139                                    Dobby    Male
# 139  140                                 Kreacher    Male
#
#                                                    Job       House  \
# 0                                              Student  Gryffindor
# 1                                              Student  Gryffindor
# 2                                              Student  Gryffindor
# 3                                           Headmaster  Gryffindor
# 4    Keeper of Keys and Grounds | Professor of Care...  Gryffindor
# ..                                                 ...         ...
# 135  Substitute professor of Care of Magical Creatu...         NaN
# 136                                                NaN         NaN
# 137           Revolutionary leader(c. 1920s[6] – 1945)         NaN
# 138  Malfoy family's house-elf (? - 1993),\nHogwart...         NaN
# 139  \nBlack family's house-elf (?-1996), \nHarry P...         NaN
#
#                                     Wand              Patronus  \
# 0            11"  Holly  phoenix feather                  Stag
# 1             12" Ash unicorn tail hair   Jack Russell terrier
# 2     10¾"  vine wood dragon heartstring                 Otter
# 3      15" Elder Thestral tail hair core               Phoenix
# 4                  16"  Oak unknown core                   NaN
# ..                                   ...                   ...
# 135                              Unknown         Non-corporeal
# 136                              Unknown                   NaN
# 137  15", Elder, Thestral tail hair core                   NaN
# 138                                  NaN                   NaN
# 139                                  NaN                   NaN
#
#                    Species              Blood status              Hair colour  \
# 0                    Human                Half-blood                    Black
# 1                    Human                Pure-blood                      Red
# 2                    Human               Muggle-born                    Brown
# 3                    Human                Half-blood  Silver| formerly auburn
# 4    Half-Human/Half-Giant   Part-Human (Half-giant)                    Black
# ..                     ...                       ...                      ...
# 135                 Human                        NaN                     Grey
# 136               Werewolf                       NaN                     Grey
# 137                 Human   Pure-blood or half-blood                    Blond
# 138              House elf                       NaN                    Green
# 139              House elf                       NaN                    White
#
#        Eye colour                                            Loyalty  \
# 0    Bright green  Albus Dumbledore | Dumbledore's Army | Order o...
# 1            Blue  Dumbledore's Army | Order of the Phoenix | Hog...
# 2           Brown  Dumbledore's Army | Order of the Phoenix | Hog...
# 3            Blue  Dumbledore's Army | Order of the Phoenix | Hog...
# 4           Black  Albus Dumbledore | Order of the Phoenix | Hogw...
# ..            ...                                                ...
# 135           NaN         Hogwarts School of Witchcraft and Wizardry
# 136           NaN                     Lord Voldemort  | Death Eaters
# 137          Blue                     Gellert Grindelwald's Acolytes
# 138           NaN                                                NaN
# 139           NaN                                                NaN
#
#                                                 Skills               Birth  \
# 0    Parseltongue| Defence Against the Dark Arts | ...        31 July 1980
# 1                 Wizard chess | Quidditch goalkeeping        1 March 1980
# 2                                    Almost everything  19 September, 1979
# 3    Considered by many to be one of the most power...    Late August 1881
# 4    Resistant to stunning spells| above average st...     6 December 1928
# ..                                                 ...                 ...
# 135                                                NaN                 NaN
# 136                                    Physical combat            Pre 1945
# 137                                           Duelling                1883
# 138  A type of magic specific to house-elves, perfo...             28 June
# 139  Magic performed without a wand which includes ...                 NaN
#
#                 Death
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3      30 June, 1997
# 4                 NaN
# ..                ...
# 135               NaN
# 136               NaN
# 137       March, 1998
# 138  Late March, 1998
# 139               NaN
#
# [140 rows x 15 columns]

# %% [markdown]
# ### Data cleaning
# * Replace missing values with "Uknown" for better statistics
# * Remove all special charcaters except for alphanumeric and space from all columns that contain straings
# * Fixing date formatting (as much as possible since the formats vary vastly)
# * For columns that should map to categorical data, map to unique value when there are various spellings

# %%
hp_data = hp_data.fillna("Unknown")

# %%
df_obj = hp_data.select_dtypes(["object"])
hp_data = df_obj.applymap(lambda x: re.sub(r'[^ \w+]', '', str(x)))

# %%
hp_data["Birth"]= hp_data["Birth"].apply(lambda x: pd.to_datetime(x, errors="coerce"))
hp_data["Death"]= hp_data["Death"].apply(lambda x: pd.to_datetime(x, errors="coerce"))
hp_data = hp_data.fillna("Unknown")

# %%
hp_data["Blood status"].unique()
hp_data["Blood status"] = hp_data["Blood status"].str.lower()
hp_data["Blood status"] = hp_data["Blood status"].replace(to_replace=["halfbloodorpureblood", "purebloodorhalfblood"], value = "pureblood or halfblood")

# %%
hp_data
# Out:
#                                         Name  Gender  \
# 0                         Harry James Potter    Male
# 1                      Ronald Bilius Weasley    Male
# 2                      Hermione Jean Granger  Female
# 3    Albus Percival Wulfric Brian Dumbledore    Male
# 4                              Rubeus Hagrid    Male
# ..                                       ...     ...
# 135                  Wilhelmina GrubblyPlank  Female
# 136                          Fenrir Greyback    Male
# 137                      Gellert Grindelwald    Male
# 138                                    Dobby    Male
# 139                                 Kreacher    Male
#
#                                                    Job       House  \
# 0                                              Student  Gryffindor
# 1                                              Student  Gryffindor
# 2                                              Student  Gryffindor
# 3                                           Headmaster  Gryffindor
# 4    Keeper of Keys and Grounds  Professor of Care ...  Gryffindor
# ..                                                 ...         ...
# 135  Substitute professorofCare of Magical Creature...     Unknown
# 136                                            Unknown     Unknown
# 137                    Revolutionary leaderc1920s61945     Unknown
# 138  Malfoy familys houseelf   1993Hogwarts kitchen...     Unknown
# 139  Black familys houseelf 1996 Harry Potters hous...     Unknown
#
#                                   Wand              Patronus  \
# 0           11  Holly  phoenix feather                  Stag
# 1            12 Ash unicorn tail hair   Jack Russell terrier
# 2    10¾  vine wood dragon heartstring                 Otter
# 3     15 Elder Thestral tail hair core               Phoenix
# 4                 16  Oak unknown core               Unknown
# ..                                 ...                   ...
# 135                            Unknown          Noncorporeal
# 136                            Unknown               Unknown
# 137   15 Elder Thestral tail hair core               Unknown
# 138                            Unknown               Unknown
# 139                            Unknown               Unknown
#
#                 Species            Blood status             Hair colour  \
# 0                 Human               halfblood                   Black
# 1                 Human               pureblood                     Red
# 2                 Human              muggleborn                   Brown
# 3                 Human               halfblood  Silver formerly auburn
# 4    HalfHumanHalfGiant      parthumanhalfgiant                   Black
# ..                  ...                     ...                     ...
# 135               Human                 unknown                    Grey
# 136            Werewolf                 unknown                    Grey
# 137               Human  pureblood or halfblood                   Blond
# 138           House elf                 unknown                   Green
# 139           House elf                 unknown                   White
#
#        Eye colour                                            Loyalty  \
# 0    Bright green  Albus Dumbledore  Dumbledores Army  Order of t...
# 1            Blue  Dumbledores Army  Order of the Phoenix  Hogwar...
# 2           Brown  Dumbledores Army  Order of the Phoenix  Hogwar...
# 3            Blue  Dumbledores Army  Order of the Phoenix  Hogwar...
# 4           Black  Albus Dumbledore  Order of the Phoenix  Hogwar...
# ..            ...                                                ...
# 135       Unknown         Hogwarts School of Witchcraft and Wizardry
# 136       Unknown                       Lord Voldemort  Death Eaters
# 137          Blue                      Gellert Grindelwalds Acolytes
# 138       Unknown                                            Unknown
# 139       Unknown                                            Unknown
#
#                                                 Skills                Birth  \
# 0    Parseltongue Defence Against the Dark Arts  Se...  1980-07-31 00:00:00
# 1                  Wizard chess  Quidditch goalkeeping  1980-03-01 00:00:00
# 2                                    Almost everything  1979-09-19 00:00:00
# 3    Considered by many to be one of the most power...              Unknown
# 4    Resistant to stunning spells above average str...  1928-12-06 00:00:00
# ..                                                 ...                  ...
# 135                                            Unknown              Unknown
# 136                                    Physical combat              Unknown
# 137                                           Duelling  1883-01-01 00:00:00
# 138  A type of magic specific to houseelves perform...              Unknown
# 139  Magic performed without a wand which includes ...              Unknown
#
#                    Death
# 0                Unknown
# 1                Unknown
# 2                Unknown
# 3    1997-06-30 00:00:00
# 4                Unknown
# ..                   ...
# 135              Unknown
# 136              Unknown
# 137  1998-03-01 00:00:00
# 138              Unknown
# 139              Unknown
#
# [140 rows x 14 columns]

# %%
hp_data.to_csv("data/clean_characters.csv")

# %%
import pandas as pd
import re
hp_data = pd.read_csv("data/clean_characters.csv")

# %%
hp_data["Skills"][0:20]
# Out:
# 0                                                   Parseltongue Defence Against the Dark Arts  Seeker
# 1                                                                  Wizard chess  Quidditch goalkeeping
# 2                                                                                    Almost everything
# 3                                Considered by many to be one of the most powerful wizards of his time
# 4                                 Resistant to stunning spells above average strength  crossbowmanship
# 5                                                                                            Herbology
# 6                                                                                               Beater
# 7                                                                                               Beater
# 8                                                                                  Chaser BatBogey hex
# 9                                                                                               Chaser
# 10                                                                                        Pyrotechnics
# 11                                                                                             Unknown
# 12                                                                                     Animagus Seeker
# 13                                                                     Animagus nonverbal magic Charms
# 14                                               Exceptionally gifted in Defence Against the Dark Arts
# 15                                                                                            Animagus
# 16                                                             Intelligent hardworking a model student
# 17    Highly skilled cursebreaker for Gringotts Wizarding Bank very intelligent past Hogwarts Head Boy
# 18                                             Highly skilled dragon trainer onetime Gryffindor Seeker
# 19                                                                  Quidditch commentary  broadcasting
# Name: Skills, dtype: object
